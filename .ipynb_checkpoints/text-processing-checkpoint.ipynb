# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
from nltk.corpus import inaugural

# %%
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
print(inaugural.raw('2017-Trump.txt'))
# Out:
# Chief Justice Roberts, President Carter, President Clinton, President Bush, President Obama, fellow Americans, and people of the world: Thank you.
#
# We, the citizens of America, are now joined in a great national effort to rebuild our country and restore its promise for all of our people. Together, we will determine the course of America and the world for many, many years to come. We will face challenges, we will confront hardships, but we will get the job done.
#
# Every 4 years, we gather on these steps to carry out the orderly and peaceful transfer of power, and we are grateful to President Obama and First Lady Michelle Obama for their gracious aid throughout this transition. They have been magnificent. Thank you.
#
# Today's ceremony, however, has very special meaning. Because today we are not merely transferring power from one administration to another or from one party to another, but we are transferring power from Washington, DC, and giving it back to you, the people.
#
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer=CountVectorizer()

# %%
speeches=[inaugural.raw('2017-Trump.txt'),inaugural.raw('2009-Obama.txt')]

# %%
vectorizer.fit(speeches)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
bag_of_words=vectorizer.transform(speeches)

# %%
print(bag_of_words)
# Out:
#   (0, 0)	1
#   (0, 1)	1
#   (0, 2)	2
#   (0, 3)	1
#   (0, 4)	5
#   (0, 5)	2
#   (0, 6)	1
#   (0, 7)	1
#   (0, 8)	9
#   (0, 9)	1
#   (0, 10)	1
#   (0, 11)	1
#   (0, 12)	14
#   (0, 13)	2
#   (0, 14)	1
#   (0, 15)	1
#   (0, 16)	1
#   (0, 17)	1
#   (0, 18)	1
#   (0, 19)	2
#   (0, 20)	20
#   (0, 21)	11
#   (0, 22)	4
#   (0, 23)	3
#   (0, 24)	76
#   :	:
#   (0, 509)	1
#   (0, 510)	1
#   (0, 511)	1
#   (0, 512)	3
#   (0, 513)	3
#   (0, 514)	4
#   (0, 515)	6
#   (0, 516)	1
#   (0, 517)	1
#   (0, 518)	43
#   (0, 519)	1
#   (0, 520)	2
#   (0, 521)	1
#   (0, 522)	8
#   (0, 523)	2
#   (0, 524)	1
#   (0, 525)	1
#   (0, 526)	1
#   (0, 527)	2
#   (0, 528)	6
#   (0, 529)	2
#   (0, 530)	1
#   (0, 531)	14
#   (0, 532)	1
#   (0, 533)	11

# %%
vectorizer.vocabulary_.get("slave")

# %%
vectorizer.get_feature_names()
# Out:
# ['20',
#  '2017',
#  'abandoned',
#  'ability',
#  'about',
#  'accept',
#  'account',
#  'achieve',
#  'across',
#  'act',
#  'action',
#  'administration',
#  'advance',
#  'advancing',
#  'adversaries',
#  'affairs',
#  'afford',
#  'afghanistan',
#  'again',
#  'against',
#  'age',
#  'ages',
#  'ago',
#  'aid',
#  'aims',
#  'airports',
#  'alarmed',
#  'all',
#  'allegiance',
#  'alliances',
#  'allow',
#  'allowing',
#  'almighty',
#  'alone',
#  'along',
#  'alongside',
#  'already',
#  'also',
#  'always',
#  'ambitions',
#  'america',
#  'american',
#  'americans',
#  'amidst',
#  'an',
#  'ancestors',
#  'and',
#  'another',
#  'answer',
#  'anyone',
#  'anything',
#  'apologize',
#  'apply',
#  'are',
#  'arguments',
#  'arlington',
#  'armies',
#  'around',
#  'arrives',
#  'as',
#  'aside',
#  'ask',
#  'assembled',
#  'assure',
#  'at',
#  'back',
#  'bad',
#  'badly',
#  'band',
#  'based',
#  'be',
#  'beautiful',
#  'became',
#  'because',
#  'become',
# ...

# %%
o2=inaugural.raw('2013-Obama.txt')

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
import nltk.corpus  
from nltk.text import Text

# %%
ob3 = Text(nltk.corpus.inaugural.words())

# %%
type(ob3)
# Out:
# nltk.text.Text

# %%
ob3.concordance('slavery') ##
# Out:
# Displaying 25 of 25 matches:
# ion was the institution of domestic slavery . Our forefathers were deeply impre
#  on the part of Congress to abolish slavery in the District of Columbia against
# tlement of the question of domestic slavery in the Territories . Congress is ne
#  Congress is neither " to legislate slavery into any Territory or State nor to
# ived into the Union with or without slavery , as their constitution may prescri
# l agree that under the Constitution slavery in the States is beyond the reach o
# ten . But this question of domestic slavery is of far graver importance than an
# o interfere with the institution of slavery in the States where it exists . I b
# pressly say . May Congress prohibit slavery in the Territories ? The Constituti
# pressly say . Must Congress protect slavery in the Territories ? The Constituti
# One section of our country believes slavery is right and ought to be extended ,
# ...

# %%
moby = text1

# %%
moby.concordance('word')
# Out:
# Displaying 25 of 76 matches:
# lone maketh the signification of the word , you deliver that which is not true
# ly still , and resolved not to say a word till spoken to . Holding a light in
#  prefix so significant and infidel a word , and yet do not thus entitle him ,
# nished with the meat and wine of the word , to the faithful man of God , this
#  Jonah upon the dry land ;' when the word of the Lord came a second time ; and
#  and seeming to hear nothing but the word " clam ," Mrs . Hussey hurried towar
#  to the kitchen door , I uttered the word " cod " with great emphasis , and re
# alliots , and what not ; but take my word for it , you never saw such a rare o
# e landlady . But all we said , not a word could we drag out of him ; I almost
# ld not move a peg , nor say a single word , nor even look at me , nor notice m
# ill yourself , Queequeg ." But not a word did he reply . Despairing of him , t
# ions about their hereafters . In one word , Queequeg , said I , rather digress
# ...

# %%
nltk.corpus.inaugural.fileids()[-2]
# Out:
# '2013-Obama.txt'

# %%
help(nltk.corpus.inaugural.words)
# Out:
# Help on method words in module nltk.corpus.reader.plaintext:
#
# words(fileids=None) method of nltk.corpus.reader.plaintext.PlaintextCorpusReader instance
#     :return: the given file(s) as a list of words
#         and punctuation symbols.
#     :rtype: list(str)

# %%
ob3=Text(nltk.corpus.inaugural.words('2009-Obama.txt'))

# %%
ob3.concordance('God')
# Out:
# Displaying 5 of 5 matches:
# n from generation to generation : the God - given promise that all are equal ,
#  our confidence -- the knowledge that God calls on us to shape an uncertain des
# nd with eyes fixed on the horizon and God ' s grace upon us , we carried forth
# y to future generations . Thank you . God bless you . And God bless the United
# ons . Thank you . God bless you . And God bless the United States of America .
