# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,5,6)
y = x*(4-x)
plt.plot(x,y)
plt.grid()
plt.show()

# %%
x = np.linspace(-2,2,41)
y = 1/(1+x**2)
plt.grid()
plt.axis("equal")
plt.plot(x,y)
plt.show()
